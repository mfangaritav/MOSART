# %% [markdown]
# Elevation changes from SAR Amplitude images
# ==============
#
# This notebook shows how to get elevation changes from SAR amplitude images using shape from shading techniques explained in (cite article). In this notebook we show the results for a Shishaldin dataset using TerraSAR-X images and an ArticDEM. Unfortunately the notebook cannot be rerun because it needs the original slc files and DEM that are not open source.
#
# ## Importing libraries
#
# 'sfs' coregisters the slc images with a DEM

# %%
# %matplotlib inline
from mosart import sfs
from mosart import lsquares
import numpy as np
import matplotlib.pyplot as plt
import h5py
import multiprocessing
from functools import partial
import matplotlib.image as image
import datetime as dt
import matplotlib.style
import matplotlib as mpl
import datetime as dt
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ## H5 file names
#
# The variable 'cor_stack' will contain the name of the h5 file where all the coregistered images and DEM will be. The variable 'pre_stack' will contain the name of the h5 file that will have the area of interest and the gradient of the given DEM.

# %%
cor_stack='projections.h5'
pre_stack='ascending_new.h5'

# %% [markdown]
# ## Coregistration of slcs
#
# In the next cell we have the rutine that coregisters all slcs images contain in the folder 'data/slcs'. The output filename will be given by cor_stack.
#
# **THIS RUTINE USES ISCE FOR COREGISTRATION**.

# %%
#Coregistering SAR images with the earliest image

sfs.coregistration_bursts('bursts_list_sen1.txt')
# Out:
# 2024-08-20 20:18:35,270 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.xml
# 2024-08-20 20:18:35,272 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.xml
# 2024-08-20 20:18:35,276 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.tiff
# 2024-08-20 20:18:35,278 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:18:54,857 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.xml
# 2024-08-20 20:18:55,191 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.xml
# 2024-08-20 20:18:55,307 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.tiff
# 2024-08-20 20:18:55,395 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:19:11,276 - hyp3_isce2.burst - INFO - Download attempt #3 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.tiff
# 2024-08-20 20:19:11,348 - hyp3_isce2.burst - INFO - Download attempt #3 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:19:26,787 - hyp3_isce2.burst - INFO - Download attempt #4 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.tiff
# 2024-08-20 20:19:26,901 - hyp3_isce2.burst - INFO - Download attempt #4 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:19:42,222 - hyp3_isce2.burst - INFO - Download attempt #5 for https://sentinel1-burst.asf.alaska.edu/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3/IW2/VV/6.tiff
# 2024-08-20 20:19:42,331 - hyp3_isce2.burst - INFO - Download attempt #5 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:19:57,815 - hyp3_isce2.burst - INFO - Download attempt #6 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3/IW2/VV/7.tiff
# 2024-08-20 20:19:59,890 - hyp3_isce2.burst - INFO - SAFEs created!
# Input XML files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/annotation/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.xml']
# Input TIFF files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/measurement/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.tiff']
# Manifest files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/manifest.safe']
# Setting IPF version to :  002.71
# Extracting orbit from annotation XML file
# Input XML files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/annotation/s1b-iw2-slc-vv-20170111t045536-20170111t045604-003796-006865-005.xml']
# Input TIFF files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/measurement/s1b-iw2-slc-vv-20170111t045536-20170111t045604-003796-006865-005.tiff']
# Manifest files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/manifest.safe']
# Setting IPF version to :  002.72
# Extracting orbit from annotation XML file
# Opening glo_30 Datasets: 100%|██████████| 4/4 [00:06<00:00,  1.58s/it]
# Reading tile metadata: 100%|██████████| 4/4 [00:00<00:00, 48913.17it/s]
# Reading tile imagery: 100%|██████████| 4/4 [00:03<00:00,  1.08it/s]
# 2024-08-20 20:20:16,915 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.tif.aux.xml: 403
# 2024-08-20 20:20:16,930 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.aux: 403
# 2024-08-20 20:20:16,943 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.AUX: 403
# 2024-08-20 20:20:16,954 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.tif.aux: 403
# 2024-08-20 20:20:16,965 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.tif.AUX: 403
# 2024-08-20 20:20:19,039 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.tif.msk: 403
# 2024-08-20 20:20:19,049 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/egm08_25.tif.MSK: 403
# fixing xml file path for file: dem/full_res.dem.wgs84
# Writing geotrans to VRT for /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84
# 2024-08-20 20:20:33,076 - isce.insar - INFO - ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
#
# 2024-08-20 20:20:33,094 - isce.insar - WARNING - Some filenames in insarApp.geocode_list configuration are different from those in InsarProc. Using names given to insarApp.
# insarApp.geocode_list = ['merged/phsig.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/filt_topophase.flat', 'merged/topophase.cor', 'merged/filt_topophase.unw.conncomp']
# InsarProc.geocode_list = ['merged/phsig.cor', 'merged/topophase.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw']
# Step processing
# Running step startup
# None
# The currently supported sensors are:  ['SENTINEL1']
# Dumping the application's pickle object _insar to file  PICKLE/startup
# The remaining steps are (in order):  ['preprocess', 'computeBaselines', 'verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step preprocess
# Input XML files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/annotation/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.xml']
# Input TIFF files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/measurement/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.tiff']
# Manifest files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/manifest.safe']
# Setting IPF version to :  002.71
# Extracting orbit from Orbit File:  orbits/S1A_OPER_AUX_POEORB_OPOD_20210312T234800_V20160720T225943_20160722T005943.EOF
# Number of Bursts before cropping:  10
# Number of Bursts after cropping:  1
# Updating burst number from 7 to 1
# Input XML files:  ['S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/annotation/s1b-iw2-slc-vv-20170111t045536-20170111t045604-003796-006865-005.xml']
# Input TIFF files:  ['S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/measurement/s1b-iw2-slc-vv-20170111t045536-20170111t045604-003796-006865-005.tiff']
# Manifest files:  ['S1B_IW_SLC__1SDV_20170111T045535_20170111T045605_003796_006865_8EF3.SAFE/manifest.safe']
# Setting IPF version to :  002.72
# Extracting orbit from Orbit File:  orbits/S1B_OPER_AUX_POEORB_OPOD_20210305T172834_V20170110T225942_20170112T005942.EOF
# Number of Bursts before cropping:  10
# Number of Bursts after cropping:  1
# Updating burst number from 8 to 1
# 2024-08-20 20:20:35,275 - isce.topsinsar.runPreprocessor - INFO -
# ####################################################################################################
#     runPreprocessor
# ----------------------------------------------------------------------------------------------------
# common.Input list of swaths to process:  = [2]
# reference.burstLength_2 = 1510
# reference.burstWidth_2 = 24505
# reference.numberOfBursts_2 = 1
# reference.sensor.ascendingnodetime = 2016-07-21 04:41:59.228706
# reference.sensor.family = topsswathslc
# reference.sensor.folder = None
# reference.sensor.imagingmode = TOPS
# reference.sensor.mission = S1A
# reference.sensor.name = topsswathslc_name
# reference.sensor.numberofbursts = 1
# reference.sensor.processingfacility = Airbus DS-Newport, United Kingdom
# reference.sensor.processingsoftwareversion = 002.71
# reference.sensor.processingsystem = Sentinel-1 IPF
# reference.sensor.spacecraftname = Sentinel-1
# secondary.burstLength_2 = 1510
# secondary.burstWidth_2 = 24420
# secondary.numberOfBursts_2 = 1
# secondary.sensor.ascendingnodetime = 2017-01-11 04:41:17.276244
# secondary.sensor.family = topsswathslc
# secondary.sensor.folder = None
# secondary.sensor.imagingmode = TOPS
# secondary.sensor.mission = S1B
# secondary.sensor.name = topsswathslc_name
# secondary.sensor.numberofbursts = 1
# secondary.sensor.processingfacility = Airbus DS-Newport, United Kingdom
# secondary.sensor.processingsoftwareversion = 002.72
# secondary.sensor.processingsystem = Sentinel-1 IPF
# secondary.sensor.spacecraftname = Sentinel-1
# ####################################################################################################
# Dumping the application's pickle object _insar to file  PICKLE/preprocess
# The remaining steps are (in order):  ['computeBaselines', 'verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# 2024-08-20 20:20:35,285 - isce.insar - INFO - ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
#
# 2024-08-20 20:20:35,296 - isce.insar - WARNING - Some filenames in insarApp.geocode_list configuration are different from those in InsarProc. Using names given to insarApp.
# insarApp.geocode_list = ['merged/phsig.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/filt_topophase.flat', 'merged/topophase.cor', 'merged/filt_topophase.unw.conncomp']
# InsarProc.geocode_list = ['merged/phsig.cor', 'merged/topophase.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw']
# Step processing
# Running step computeBaselines
# Estimated burst offset:  0
# No swaths contain any burst overlaps ... cannot continue for interferometry applications
# 2024-08-20 20:20:35,428 - isce.topsinsar.runPreprocessor - INFO -
# ####################################################################################################
#     runComputeBaseline
# ----------------------------------------------------------------------------------------------------
# baseline.IW-2 Bpar at midrange for first common burst = -110.75892965048017
# baseline.IW-2 Bpar at midrange for last common burst = -110.75892965048017
# baseline.IW-2 Bperp at midrange for first common burst = 10.492259758014418
# baseline.IW-2 Bperp at midrange for last common burst = 10.492259758014418
# baseline.IW-2 First common burst in reference = 0
# baseline.IW-2 First common burst in secondary = 0
# baseline.IW-2 Last common burst in reference = 1
# baseline.IW-2 Last common burst in secondary = 1
# baseline.IW-2 Number of bursts in reference = 1
# baseline.IW-2 Number of bursts in secondary = 1
# baseline.IW-2 Number of common bursts = 1
# ####################################################################################################
# Dumping the application's pickle object _insar to file  PICKLE/computeBaselines
# The remaining steps are (in order):  ['verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step verifyDEM
# Dumping the application's pickle object _insar to file  PICKLE/verifyDEM
# The remaining steps are (in order):  ['topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step topo
# 2024-08-20 20:20:35,482 - isce.zerodop.topozero - WARNING - Default Peg heading set to: -0.277402639631078
# C pointer already created. Finalize and recreate if image dimensions changed.
# C pointer already created. Finalize and recreate if image dimensions changed.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 1
# 849103	2.32956
# GDAL open (R): /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84.vrt
# API open (WR): geom_reference/IW2/lat_01.rdr
# API open (WR): geom_reference/IW2/lon_01.rdr
# API open (WR): geom_reference/IW2/hgt_01.rdr
# API open (WR): geom_reference/IW2/los_01.rdr
#  Initializing biquintic interpolator
#  Orbit interpolation method: hermite
#  Max threads used:            2
#  DEM parameters:
#  Dimensions:         7200        7200
#  Top Left:   -169.00000000000000        55.000100000000003
#  Spacing:    4.1666700000000001E-004  -2.7777800000000001E-004
#  Lon:   -169.00000000000000       -166.00041426700000
#  Lat:    53.000376178000003        55.000100000000003
#
#  Estimated DEM bounds needed for global height range:
#  Lon:   -168.47334274855106       -166.59378363706645
#  Lat:    53.625664717769176        54.269133061171075
#
#  Actual DEM bounds used:
#  Dimensions:         4513        2318
#  Top Left:   -168.47374957900001        54.269266082000001
#  Spacing:    4.1666700000000001E-004  -2.7777800000000001E-004
#  Lon:   -168.47374957900001       -166.59374807500001
#  Lat:    53.625654455999999        54.269266082000001
#  Lines:         2632        4949
#  Pixels:         1264        5776
#  Max DEM height:    1831.95410
#  Primary iterations:           25
#  Secondary iterations:           10
#  Distance threshold :    5.0000000000000003E-002
#  Processing line:            1   7589.2773305448663
#  Dopplers:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#  Processing line:         1001   7589.2392200458544
#  Dopplers:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#  Total convergence:    36982200  out of     37002550
# API close:  geom_reference/IW2/lat_01.rdr
# API open (R): geom_reference/IW2/lat_01.rdr
# API close:  geom_reference/IW2/lat_01.rdr
# API close:  geom_reference/IW2/lon_01.rdr
# API open (R): geom_reference/IW2/lon_01.rdr
# API close:  geom_reference/IW2/lon_01.rdr
# API close:  geom_reference/IW2/hgt_01.rdr
# API open (R): geom_reference/IW2/hgt_01.rdr
# API close:  geom_reference/IW2/hgt_01.rdr
# API close:  geom_reference/IW2/los_01.rdr
# API open (R): geom_reference/IW2/los_01.rdr
# API close:  geom_reference/IW2/los_01.rdr
# 2024-08-20 20:22:06,411 - isce.topsinsar.topo - INFO -
# ####################################################################################################
#     runTopo
# ----------------------------------------------------------------------------------------------------
# topo.Bounding box for burst 0 - IW-2 = [53.77689487122227, 54.10470016023586, -168.31212574799764, -166.88304157152822]
# topo.Dem Used = /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84
# topo.Number of common bursts IW-2 = 1
# topo.Number of lines for burst 0 - IW-2 = 1510
# topo.Number of pixels for bursts 0 - IW-2 = 24505
# topo.Overall bounding box = [53.77689487122227, 54.10470016023586, -168.31212574799764, -166.88304157152822]
# ####################################################################################################
# GDAL close: /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84.vrt
# Dumping the application's pickle object _insar to file  PICKLE/topo
# The remaining steps are (in order):  ['subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step subsetoverlaps
# Dumping the application's pickle object _insar to file  PICKLE/subsetoverlaps
# The remaining steps are (in order):  ['coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step coarseoffsets
# Dumping the application's pickle object _insar to file  PICKLE/coarseoffsets
# The remaining steps are (in order):  ['coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step coarseresamp
# Dumping the application's pickle object _insar to file  PICKLE/coarseresamp
# The remaining steps are (in order):  ['overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step overlapifg
# Dumping the application's pickle object _insar to file  PICKLE/overlapifg
# The remaining steps are (in order):  ['prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step prepesd
# Dumping the application's pickle object _insar to file  PICKLE/prepesd
# The remaining steps are (in order):  ['esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step esd
# Dumping the application's pickle object _insar to file  PICKLE/esd
# The remaining steps are (in order):  ['rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step rangecoreg
# Dumping the application's pickle object _insar to file  PICKLE/rangecoreg
# The remaining steps are (in order):  ['fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step fineoffsets
# 2024-08-20 20:22:06,475 - isce.topsinsar.fineoffsets - INFO - IW2 - Burst 0 of reference matched with Burst 0 of secondary
# 2024-08-20 20:22:06,494 - isce.topsinsar.fineoffsets - INFO - Additional time offset applied in geo2rdr: 0.0 secs
# GDAL open (R): geom_reference/IW2/lat_01.rdr.vrt
# GDAL open (R): geom_reference/IW2/lon_01.rdr.vrt
# GDAL open (R): geom_reference/IW2/hgt_01.rdr.vrt
# 2024-08-20 20:22:06,498 - isce.topsinsar.fineoffsets - INFO - Additional range offset applied in geo2rdr: 0.0 m
# Turning off bistatic delay correction term by default.
# API open (WR): fine_offsets/IW2/range_01.off
# API open (WR): fine_offsets/IW2/azimuth_01.off
#  Orbit interpolation method: hermite
#  threads           2
#  Starting Acquisition time:    17755.888458000001
#  Stop Acquisition time:    17758.990292456700
#  Azimuth line spacing in secs:    2.0555562999999980E-003
#  Near Range in m:    849102.88809799426
#  Far  Range in m:    905988.46537722775
#  Range sample spacing in m:    2.3295621147153232
#  Radar Image Lines:         1510
#  Radar Image Width:        24420
#  reading dem ...
#  Geocoded Lines:          1510
#  Geocoded Samples:       24505
#  Dopplers:    0.0000000000000000        0.0000000000000000
#  geo2rdr on            2  threads...
#  Processing line:            1           0
#  Processing line:         1001      421750
#  Number of pixels outside the image:       489580
#  Number of pixels with valid data:       34976141
#  Number of pixels that converged:           24215
#  elapsed time =    71.6015625      seconds
# API close:  fine_offsets/IW2/range_01.off
# API open (R): fine_offsets/IW2/range_01.off
# API close:  fine_offsets/IW2/range_01.off
# API close:  fine_offsets/IW2/azimuth_01.off
# API open (R): fine_offsets/IW2/azimuth_01.off
# API close:  fine_offsets/IW2/azimuth_01.off
# GDAL close: geom_reference/IW2/lat_01.rdr.vrt
# GDAL close: geom_reference/IW2/lon_01.rdr.vrt
# GDAL close: geom_reference/IW2/hgt_01.rdr.vrt
# Dumping the application's pickle object _insar to file  PICKLE/fineoffsets
# The remaining steps are (in order):  ['fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step fineresamp
# Shifts IW-2:  {0: 0}
# Chi squared: 0.000019
# Misfit radians - Max: 5.745850648963824e-05 , Min : -0.00011063159763580188
# 2024-08-20 20:23:18,239 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-08-20 20:23:18,241 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24420 which is the width of the slc image.
# 2024-08-20 20:23:18,242 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11254.4	-591.214	23.6657	1.27988
# -44719.3	2217.68	-87.8465	-4.80974
# 44423.1	-2072.34	81.5037	4.4829
# -9.79897e-09	1.15424e-08	-4.14768e-09	0
# 6.81012e-09	-3.27673e-09	0	0
# -1.83229e-09	0	0	0
# GDAL open (R): secondary/IW2/burst_01.slc.vrt
# API open (WR): fine_coreg/IW2/burst_01.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11254.4	-591.214	23.6657	1.27988
# -44719.3	2217.68	-87.8465	-4.80974
# 44423.1	-2072.34	81.5037	4.4829
# -9.79897e-09	1.15424e-08	-4.14768e-09	0
# 6.81012e-09	-3.27673e-09	0	0
# -1.83229e-09	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_01.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_01.off.vrt
# Polynomial Order: 0 - by - 2
# 0.87075	-526.534	82314.8
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24420  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        24505 pixels
#         1510 lines
#
#  Number of threads:            2
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11254.4	-591.214	23.6657	1.27988
# -44719.3	2217.68	-87.8465	-4.80974
# 44423.1	-2072.34	81.5037	4.4829
# -9.79897e-09	1.15424e-08	-4.14768e-09	0
# 6.81012e-09	-3.27673e-09	0	0
# -1.83229e-09	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.87075	-526.534	82314.8
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    21.5234375
# GDAL close: fine_offsets/IW2/range_01.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_01.off.vrt
# GDAL close: secondary/IW2/burst_01.slc.vrt
# API close:  fine_coreg/IW2/burst_01.slc
# API open (R): fine_coreg/IW2/burst_01.slc
# API close:  fine_coreg/IW2/burst_01.slc
# Adjust valid samples
# Before:  78 24352
# Offsets :  47.344322204589844 47.73281478881836
# Adjust valid lines
# Before:  24 1463
# Offsets :  -11.881386756896973 -11.807868957519531
# After:  41 1454
# Dumping the application's pickle object _insar to file  PICKLE/fineresamp
# The remaining steps are (in order):  ['ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# 2024-08-20 20:24:36,424 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.xml
# 2024-08-20 20:24:36,429 - hyp3_isce2.burst - INFO - Download attempt #1 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.tiff
# 2024-08-20 20:24:53,054 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.xml
# 2024-08-20 20:24:53,135 - hyp3_isce2.burst - INFO - Download attempt #2 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.tiff
# 2024-08-20 20:25:08,596 - hyp3_isce2.burst - INFO - Download attempt #3 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.tiff
# 2024-08-20 20:25:24,060 - hyp3_isce2.burst - INFO - Download attempt #4 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.tiff
# 2024-08-20 20:25:39,531 - hyp3_isce2.burst - INFO - Download attempt #5 for https://sentinel1-burst.asf.alaska.edu/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B/IW2/VV/7.tiff
# 2024-08-20 20:25:41,783 - hyp3_isce2.burst - INFO - SAFEs created!
# Input XML files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/annotation/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.xml']
# Input TIFF files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/measurement/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.tiff']
# Manifest files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/manifest.safe']
# Setting IPF version to :  002.71
# Extracting orbit from annotation XML file
# Input XML files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/annotation/s1b-iw2-slc-vv-20170511t045538-20170511t045605-005546-009b6c-005.xml']
# Input TIFF files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/measurement/s1b-iw2-slc-vv-20170511t045538-20170511t045605-005546-009b6c-005.tiff']
# Manifest files:  ['/home/jovyan/notebooks/ASF/newMOSART/coreg/S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/manifest.safe']
# Setting IPF version to :  002.82
# Extracting orbit from annotation XML file
# 2024-08-20 20:25:49,199 - isce.insar - INFO - ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
#
# 2024-08-20 20:25:49,211 - isce.insar - WARNING - Some filenames in insarApp.geocode_list configuration are different from those in InsarProc. Using names given to insarApp.
# insarApp.geocode_list = ['merged/phsig.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/filt_topophase.flat', 'merged/topophase.cor', 'merged/filt_topophase.unw.conncomp']
# InsarProc.geocode_list = ['merged/phsig.cor', 'merged/topophase.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw']
# Step processing
# Running step startup
# None
# The currently supported sensors are:  ['SENTINEL1']
# Dumping the application's pickle object _insar to file  PICKLE/startup
# The remaining steps are (in order):  ['preprocess', 'computeBaselines', 'verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step preprocess
# Input XML files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/annotation/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.xml']
# Input TIFF files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/measurement/s1a-iw2-slc-vv-20160721t045621-20160721t045649-012242-013041-002.tiff']
# Manifest files:  ['S1A_IW_SLC__1SSV_20160721T045620_20160721T045650_012242_013041_17A3.SAFE/manifest.safe']
# Setting IPF version to :  002.71
# Extracting orbit from Orbit File:  orbits/S1A_OPER_AUX_POEORB_OPOD_20210312T234800_V20160720T225943_20160722T005943.EOF
# Number of Bursts before cropping:  10
# Number of Bursts after cropping:  1
# Updating burst number from 7 to 1
# Input XML files:  ['S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/annotation/s1b-iw2-slc-vv-20170511t045538-20170511t045605-005546-009b6c-005.xml']
# Input TIFF files:  ['S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/measurement/s1b-iw2-slc-vv-20170511t045538-20170511t045605-005546-009b6c-005.tiff']
# Manifest files:  ['S1B_IW_SLC__1SDV_20170511T045537_20170511T045606_005546_009B6C_573B.SAFE/manifest.safe']
# Setting IPF version to :  002.82
# Extracting orbit from Orbit File:  orbits/S1B_OPER_AUX_POEORB_OPOD_20210307T161216_V20170510T225942_20170512T005942.EOF
# Number of Bursts before cropping:  10
# Number of Bursts after cropping:  1
# Updating burst number from 8 to 1
# 2024-08-20 20:25:51,392 - isce.topsinsar.runPreprocessor - INFO -
# ####################################################################################################
#     runPreprocessor
# ----------------------------------------------------------------------------------------------------
# common.Input list of swaths to process:  = [2]
# reference.burstLength_2 = 1510
# reference.burstWidth_2 = 24505
# reference.numberOfBursts_2 = 1
# reference.sensor.ascendingnodetime = 2016-07-21 04:41:59.228706
# reference.sensor.family = topsswathslc
# reference.sensor.folder = None
# reference.sensor.imagingmode = TOPS
# reference.sensor.mission = S1A
# reference.sensor.name = topsswathslc_name
# reference.sensor.numberofbursts = 1
# reference.sensor.processingfacility = Airbus DS-Newport, United Kingdom
# reference.sensor.processingsoftwareversion = 002.71
# reference.sensor.processingsystem = Sentinel-1 IPF
# reference.sensor.spacecraftname = Sentinel-1
# secondary.burstLength_2 = 1510
# secondary.burstWidth_2 = 24421
# secondary.numberOfBursts_2 = 1
# secondary.sensor.ascendingnodetime = 2017-05-11 04:41:18.785577
# secondary.sensor.family = topsswathslc
# secondary.sensor.folder = None
# secondary.sensor.imagingmode = TOPS
# secondary.sensor.mission = S1B
# secondary.sensor.name = topsswathslc_name
# secondary.sensor.numberofbursts = 1
# secondary.sensor.processingfacility = DLR-Oberpfaffenhofen, Germany
# secondary.sensor.processingsoftwareversion = 002.82
# secondary.sensor.processingsystem = Sentinel-1 IPF
# secondary.sensor.spacecraftname = Sentinel-1
# ####################################################################################################
# Dumping the application's pickle object _insar to file  PICKLE/preprocess
# The remaining steps are (in order):  ['computeBaselines', 'verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# 2024-08-20 20:25:51,402 - isce.insar - INFO - ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.6.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20230418, CURRENT_SVN_REVISION =
#
# 2024-08-20 20:25:51,414 - isce.insar - WARNING - Some filenames in insarApp.geocode_list configuration are different from those in InsarProc. Using names given to insarApp.
# insarApp.geocode_list = ['merged/phsig.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/filt_topophase.flat', 'merged/topophase.cor', 'merged/filt_topophase.unw.conncomp']
# InsarProc.geocode_list = ['merged/phsig.cor', 'merged/topophase.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw']
# Step processing
# Running step computeBaselines
# Estimated burst offset:  0
# No swaths contain any burst overlaps ... cannot continue for interferometry applications
# 2024-08-20 20:25:51,546 - isce.topsinsar.runPreprocessor - INFO -
# ####################################################################################################
#     runComputeBaseline
# ----------------------------------------------------------------------------------------------------
# baseline.IW-2 Bpar at midrange for first common burst = -46.193704255141846
# baseline.IW-2 Bpar at midrange for last common burst = -46.193704255141846
# baseline.IW-2 Bperp at midrange for first common burst = 70.39853879094613
# baseline.IW-2 Bperp at midrange for last common burst = 70.39853879094613
# baseline.IW-2 First common burst in reference = 0
# baseline.IW-2 First common burst in secondary = 0
# baseline.IW-2 Last common burst in reference = 1
# baseline.IW-2 Last common burst in secondary = 1
# baseline.IW-2 Number of bursts in reference = 1
# baseline.IW-2 Number of bursts in secondary = 1
# baseline.IW-2 Number of common bursts = 1
# ####################################################################################################
# Dumping the application's pickle object _insar to file  PICKLE/computeBaselines
# The remaining steps are (in order):  ['verifyDEM', 'topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step verifyDEM
# Dumping the application's pickle object _insar to file  PICKLE/verifyDEM
# The remaining steps are (in order):  ['topo', 'subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step topo
# 2024-08-20 20:25:51,591 - isce.zerodop.topozero - WARNING - Default Peg heading set to: -0.277402639631078
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 1
# 849103	2.32956
# GDAL open (R): /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84.vrt
# API open (WR): geom_reference/IW2/lat_01.rdr
# API open (WR): geom_reference/IW2/lon_01.rdr
# API open (WR): geom_reference/IW2/hgt_01.rdr
# API open (WR): geom_reference/IW2/los_01.rdr
# C pointer already created. Finalize and recreate if image dimensions changed.
# C pointer already created. Finalize and recreate if image dimensions changed.
#  Initializing biquintic interpolator
#  Orbit interpolation method: hermite
#  Max threads used:            2
#  DEM parameters:
#  Dimensions:         7200        7200
#  Top Left:   -169.00000000000000        55.000100000000003
#  Spacing:    4.1666700000000001E-004  -2.7777800000000001E-004
#  Lon:   -169.00000000000000       -166.00041426700000
#  Lat:    53.000376178000003        55.000100000000003
#
#  Estimated DEM bounds needed for global height range:
#  Lon:   -168.47334274855106       -166.59378363706645
#  Lat:    53.625664717769176        54.269133061171075
#
#  Actual DEM bounds used:
#  Dimensions:         4513        2318
#  Top Left:   -168.47374957900001        54.269266082000001
#  Spacing:    4.1666700000000001E-004  -2.7777800000000001E-004
#  Lon:   -168.47374957900001       -166.59374807500001
#  Lat:    53.625654455999999        54.269266082000001
#  Lines:         2632        4949
#  Pixels:         1264        5776
#  Max DEM height:    1831.95410
#  Primary iterations:           25
#  Secondary iterations:           10
#  Distance threshold :    5.0000000000000003E-002
#  Processing line:            1   7589.2773305448663
#  Dopplers:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#  Processing line:         1001   7589.2392200458544
#  Dopplers:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#  Total convergence:    36981935  out of     37002550
# API close:  geom_reference/IW2/lat_01.rdr
# API open (R): geom_reference/IW2/lat_01.rdr
# API close:  geom_reference/IW2/lat_01.rdr
# API close:  geom_reference/IW2/lon_01.rdr
# API open (R): geom_reference/IW2/lon_01.rdr
# API close:  geom_reference/IW2/lon_01.rdr
# API close:  geom_reference/IW2/hgt_01.rdr
# API open (R): geom_reference/IW2/hgt_01.rdr
# API close:  geom_reference/IW2/hgt_01.rdr
# API close:  geom_reference/IW2/los_01.rdr
# API open (R): geom_reference/IW2/los_01.rdr
# API close:  geom_reference/IW2/los_01.rdr
# 2024-08-20 20:27:22,827 - isce.topsinsar.topo - INFO -
# ####################################################################################################
#     runTopo
# ----------------------------------------------------------------------------------------------------
# topo.Bounding box for burst 0 - IW-2 = [53.77689487122227, 54.10470016023586, -168.31212574799764, -166.88304157152822]
# topo.Dem Used = /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84
# topo.Number of common bursts IW-2 = 1
# topo.Number of lines for burst 0 - IW-2 = 1510
# topo.Number of pixels for bursts 0 - IW-2 = 24505
# topo.Overall bounding box = [53.77689487122227, 54.10470016023586, -168.31212574799764, -166.88304157152822]
# ####################################################################################################
# GDAL close: /home/jovyan/notebooks/ASF/newMOSART/coreg/dem/full_res.dem.wgs84.vrt
# Dumping the application's pickle object _insar to file  PICKLE/topo
# The remaining steps are (in order):  ['subsetoverlaps', 'coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step subsetoverlaps
# Dumping the application's pickle object _insar to file  PICKLE/subsetoverlaps
# The remaining steps are (in order):  ['coarseoffsets', 'coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step coarseoffsets
# Dumping the application's pickle object _insar to file  PICKLE/coarseoffsets
# The remaining steps are (in order):  ['coarseresamp', 'overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step coarseresamp
# Dumping the application's pickle object _insar to file  PICKLE/coarseresamp
# The remaining steps are (in order):  ['overlapifg', 'prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step overlapifg
# Dumping the application's pickle object _insar to file  PICKLE/overlapifg
# The remaining steps are (in order):  ['prepesd', 'esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step prepesd
# Dumping the application's pickle object _insar to file  PICKLE/prepesd
# The remaining steps are (in order):  ['esd', 'rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step esd
# Dumping the application's pickle object _insar to file  PICKLE/esd
# The remaining steps are (in order):  ['rangecoreg', 'fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step rangecoreg
# Dumping the application's pickle object _insar to file  PICKLE/rangecoreg
# The remaining steps are (in order):  ['fineoffsets', 'fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step fineoffsets
# 2024-08-20 20:27:22,896 - isce.topsinsar.fineoffsets - INFO - IW2 - Burst 0 of reference matched with Burst 0 of secondary
# GDAL open (R): geom_reference/IW2/lat_01.rdr.vrt
# GDAL open (R): geom_reference/IW2/lon_01.rdr.vrt
# 2024-08-20 20:27:22,910 - isce.topsinsar.fineoffsets - INFO - Additional time offset applied in geo2rdr: 0.0 secs
# GDAL open (R): geom_reference/IW2/hgt_01.rdr.vrt
# 2024-08-20 20:27:22,911 - isce.topsinsar.fineoffsets - INFO - Additional range offset applied in geo2rdr: 0.0 m
# Turning off bistatic delay correction term by default.
# API open (WR): fine_offsets/IW2/range_01.off
# API open (WR): fine_offsets/IW2/azimuth_01.off
#  Orbit interpolation method: hermite
#  threads           2
#  Starting Acquisition time:    17757.366006000000
#  Stop Acquisition time:    17760.467840456698
#  Azimuth line spacing in secs:    2.0555562999999980E-003
#  Near Range in m:    849102.88809799426
#  Far  Range in m:    905990.79493934242
#  Range sample spacing in m:    2.3295621147153232
#  Radar Image Lines:         1510
#  Radar Image Width:        24421
#  reading dem ...
#  Geocoded Lines:          1510
#  Geocoded Samples:       24505
#  Dopplers:    0.0000000000000000        0.0000000000000000
#  geo2rdr on            2  threads...
#  Processing line:            1           0
#  Processing line:         1001      223694
#  Number of pixels outside the image:       277244
#  Number of pixels with valid data:       35178321
#  Number of pixels that converged:           23367
#  elapsed time =    70.2578125      seconds
# API close:  fine_offsets/IW2/range_01.off
# API open (R): fine_offsets/IW2/range_01.off
# API close:  fine_offsets/IW2/range_01.off
# API close:  fine_offsets/IW2/azimuth_01.off
# API open (R): fine_offsets/IW2/azimuth_01.off
# API close:  fine_offsets/IW2/azimuth_01.off
# GDAL close: geom_reference/IW2/lat_01.rdr.vrt
# GDAL close: geom_reference/IW2/lon_01.rdr.vrt
# GDAL close: geom_reference/IW2/hgt_01.rdr.vrt
# Dumping the application's pickle object _insar to file  PICKLE/fineoffsets
# The remaining steps are (in order):  ['fineresamp', 'ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']
# Running step fineresamp
# Shifts IW-2:  {0: 0}
# Chi squared: 0.000063
# Misfit radians - Max: 0.00024615465554234106 , Min : -0.00019497361608955543
# 2024-08-20 20:28:33,292 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-08-20 20:28:33,293 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24421 which is the width of the slc image.
# 2024-08-20 20:28:33,293 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11254.8	-515.716	2.35799	0.767874
# -44721.1	2067.71	-45.7261	-3.76575
# 44424.9	-2072.39	81.5056	4.48312
# -1.00475e-08	1.19516e-08	-4.30099e-09	0
# 6.96645e-09	-3.37973e-09	0	0
# -1.86424e-09	0	0	0
# GDAL open (R): secondary/IW2/burst_01.slc.vrt
# API open (WR): fine_coreg/IW2/burst_01.slc
#
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11254.8	-515.716	2.35799	0.767874
# -44721.1	2067.71	-45.7261	-3.76575
# 44424.9	-2072.39	81.5056	4.48312
# -1.00475e-08	1.19516e-08	-4.30099e-09	0
# 6.96645e-09	-3.37973e-09	0	0
# -1.86424e-09	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_01.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_01.off.vrt
# Polynomial Order: 0 - by - 2
# 0.256439	150.198	-249301
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24421  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        24505 pixels
#         1510 lines
#
#  Number of threads:            2
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11254.8	-515.716	2.35799	0.767874
# -44721.1	2067.71	-45.7261	-3.76575
# 44424.9	-2072.39	81.5056	4.48312
# -1.00475e-08	1.19516e-08	-4.30099e-09	0
# 6.96645e-09	-3.37973e-09	0	0
# -1.86424e-09	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.256439	150.198	-249301
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    21.1015625
# GDAL close: fine_offsets/IW2/range_01.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_01.off.vrt
# GDAL close: secondary/IW2/burst_01.slc.vrt
# API close:  fine_coreg/IW2/burst_01.slc
# API open (R): fine_coreg/IW2/burst_01.slc
# API close:  fine_coreg/IW2/burst_01.slc
# Adjust valid samples
# Before:  78 24352
# Offsets :  18.544153213500977 21.054744720458984
# Adjust valid lines
# Before:  24 1463
# Offsets :  -4.777726650238037 -4.742560863494873
# After:  33 1455
# Dumping the application's pickle object _insar to file  PICKLE/fineresamp
# The remaining steps are (in order):  ['ion', 'burstifg', 'mergebursts', 'filter', 'unwrap', 'unwrap2stage', 'geocode', 'denseoffsets', 'filteroffsets', 'geocodeoffsets']

# %% [markdown]
# ### Plotting coregistered image and AOI
#
# 'sfs' helps to get the area of interest in radar coordinates using a lon/lat box.

# %%
# %matplotlib widget
#Reading h5 file with coregistered images
h5i=h5py.File(cor_stack,'r')
keys=[key for key in h5i.keys() if key.isdigit()]
lonrdr=h5i['lon'][:]
latrdr=h5i['lat'][:]
amps=h5i[keys[2]][:]
h5i.close()

#Getting AOI in radar coordinates corresponding to certain longitudes and latitudes
xs=[4200,4600]
ys=[990,1100]
x0=xs[0]
y0=ys[0]
xsizet=xs[-1]-xs[0]
ysizet=ys[-1]-ys[0]
#x0,y0,xsizet,ysizet=sfs.get_box2(lonrdr,latrdr,lons=lons,lats=lats)

#Plotting a coregistered image and the AOI
plt.figure()
plt.title('Ascending ('+keys[1]+')')
plt.imshow(amps,cmap='gray',vmin=0,vmax=200)
plt.colorbar(label='Intensity',orientation='horizontal')
#plt.quiver(1000,4000,0,-1500,units='x',color='magenta',scale=1)
#plt.plot([1000,1500],[4000,4000],color='magenta')
plt.plot([x0,x0,x0+xsizet,x0+xsizet,x0],[y0,y0+ysizet,y0+ysizet,y0,y0],color='red',label='AOI')
#plt.text(1200,3800,'look',color='magenta')
#plt.text(100,5000,'flight',color='magenta')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')
#plt.legend()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Plots for AOI
#
# Here we plot the area of interest around the Shishaldin crater and the gradient of the ArcticDEM.

# %%
from skimage.restoration import denoise_nl_means

amps_clip=amps[ys[0]:ys[1],xs[0]:xs[1]]

sigma_amp=20
patch_kw = dict(patch_size=5,      # 5x5 patches
                patch_distance=5,  # 13x13 search area
                )
famps=denoise_nl_means(amps_clip, h=0.6 * sigma_amp, sigma=sigma_amp, fast_mode=True, **patch_kw)

plt.figure()
plt.title('Unfiltered')
plt.imshow(amps_clip,cmap='gray',vmin=0,vmax=200)
plt.colorbar(label='Intensity',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')

plt.figure()
plt.title('Filtered')
plt.imshow(famps,cmap='gray',vmin=0,vmax=200)
plt.colorbar(label='Intensity',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Preprocessing
#
# The 'preprocessing' function clip the AOI and calculates the gradient of the given DEM along range coordinates

# %%
#Creating new h5file clipping the AOI and calculating DEM gradient
sfs.preprocessing(xs=xs,ys=ys,projections=cor_stack,output=pre_stack,sigma_amp=sigma_amp,patch_kw=patch_kw)
# Out:
# Preprocessing for  20160721
# Preprocessing for  20170111
# Preprocessing for  20170511

# %% [markdown]
# ## Making Weight matrix
#
# This cell creates the weight matrix for the inversion

# %%
# %matplotlib widget
#Reading amplitude image for the AOI
h5i=h5py.File(pre_stack,'r')
keys=[key for key in h5i.keys() if key.isdigit()]
amp=h5i[keys[0]][:]
grd=h5i['grad'][:]
dem=h5i['dem'][:]
tamps=np.array([h5i[key][:] for key in keys])
h5i.close()

weights=np.ones(tamps.shape)*0.5
waters=np.full(tamps.shape, True)
tgrddefs=[]
for i,amps in enumerate(tamps):
    water=amps[:,350::]
    cond=np.logical_and(np.percentile(water,10)<amps,amps<np.percentile(water,90))
    cond1=dem>13.2
    waters[i,:,:]=cond

    condd=np.logical_and(np.logical_not(cond),cond1)
    weights[i,:,:][condd]=1
    
plt.figure()
plt.title('Weight')
plt.imshow(weights[0,:,:])
plt.colorbar(orientation='horizontal',label='Weight')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Reconstruction of DEMs
#
# The next cells shows the process to construct a DEM per amplitude image
#
# ### Standard deviation on amplitude images
#
# We need to calculate the standar deviation on the amplitude images through time, to assign weights when the inversion is made

# %% [markdown]
# ### Construction of DEMs
#
# The library 'lsquares' makes the inversions using a least squares approach. Here we paralellize to optimize the calculation time.

# %%
#Calculate standard deviation on the amplitude images
#sfs.calc_std(pre_stack)

#Construction of DEMs
demdefs=[]
def onedem(i,keys,weights,waters):
    key=keys[i]
    weight=weights[i,:,:]
    water=waters[i,:,:]
    #water=None
    demdef,grddef,weights=lsquares.getdem(key,h5file=pre_stack,weight=weight,water=water)
    return demdef,grddef,'d'
pool = multiprocessing.Pool(processes=13)
subrutina=partial(onedem,keys=keys,weights=weights,waters=waters)
demdefs,grddefs,nada=zip(*pool.map(subrutina, range(len(keys))))
pool.close()
pool.join()
# Out:
# Start DEM for Start DEM for 20160721Start DEM for20170111
#
# 20170511
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jovyan/.local/envs/hyp3-isce2-test/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# Finished DEM for 20170511
# Finished DEM for 20160721
# Finished DEM for 20170111

# %% [markdown]
# ### Plot of ArticDEM and reconstructed DEM
#
# Here we show the original ArticDEM and a reconstructed DEM using the amplitude image on November 3, 2019

# %%
#Plot one uncorrected DEM
plt.figure()
plt.title('STRM DEM')
plt.imshow(dem,vmin=13,vmax=50)
plt.colorbar(label='Elevation (meters)',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')

plt.figure()
plt.title('Reconstructed DEM (20191103)')
plt.imshow(demdefs[1],vmin=13,vmax=50)
plt.colorbar(label='Elevation (meters)',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
reference=0

changes=[]
for demdef in demdefs:
    changes.append(demdef-demdefs[reference])
changes=np.array(changes)

index=0
plt.figure()
plt.title('Elevation changes '+keys[index])
plt.imshow(changes[index],vmin=-15,vmax=15)
plt.colorbar(label='Elevation (meters)',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')

index=1
plt.figure()
plt.title('Elevation changes '+keys[index])
plt.imshow(changes[index],vmin=-15,vmax=15)
plt.colorbar(label='Elevation (meters)',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')

index=2
plt.figure()
plt.title('Elevation changes '+keys[index])
plt.imshow(changes[index],vmin=-15,vmax=15)
plt.colorbar(label='Elevation (meters)',orientation='horizontal')
plt.xlabel('Range (px)')
plt.ylabel('Azimuth (px)')


plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
